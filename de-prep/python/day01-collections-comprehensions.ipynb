# %% [markdown]
# ### Write code to build a dict showing failure count per pipeline —
# e.g. {"orders_etl": 1, "users_etl": 1, "logs_etl": 0}.

# %%
runs = [
    {"pipeline": "orders_etl", "status": "success", "runtime_min": 12},
    {"pipeline": "users_etl", "status": "failed", "runtime_min": 3},
    {"pipeline": "orders_etl", "status": "failed", "runtime_min": 8},
    {"pipeline": "logs_etl", "status": "success", "runtime_min": 45},
    {"pipeline": "orders_etl", "status": "success", "runtime_min": 15},
]

for i in runs:
    for j in i:
        print(i,j+"\n")

# %%
# Get the 3 longest runtimes, sorted descending.
# Get the average runtime.

runtimes = [12, 45, 3, 8, 15, 60, 2]
runtimes.sort()
print(runtimes[:3:-1])
print(sum(runtimes)/len(runtimes))
# Out:
# [60, 45, 15]
# 20.714285714285715
